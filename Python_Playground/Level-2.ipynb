# %% [markdown]
# ## Python OOP: Basic to Advanced

# %% [markdown]
# ## Classes and Objects
#
# A class is a blueprint. An object (instance) is something built from that blueprint.

# %%
class Dog:
    def __init__(self, name, breed):
        self.name=name
        self.breed=breed

    def bark(self):
        return f"{self.name} says Woof!"

d = Dog("Rex", "Labrador")
print(d.bark())
print(d.name, d.breed)
# Out:
# Rex says Woof!
# Rex Labrador

# %% [markdown]
# ## Practice:
#
# 1. Create a Book class with title, author, pages. Add a method summary() that returns a formatted string.
# 2. Create a BankAccount class with balance starting at 0, and methods deposit(amount) and withdraw(amount).

# %%
class Book:
    def __init__(self,title,author,pages):
        self.title=title
        self.author=author
        self.pages=pages

    def Summary(self):
        return f"{self.title} is the book with total number of pages - {self.pages} written by {self.author}"

book = Book("Atomic Habits", "James Clear", "300")
print(book.Summary())
# Out:
# Atomic Habits is the book with total number of pages - 300 written by James Clear

# %% [markdown]
# Create a BankAccount class with balance starting at 0, and methods deposit(amount) and withdraw(amount).

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.balance=balance

    def deposit(self, amount):
        if amount>0:
            self.balance += amount
            
        elif self.balance < 0:
            self.balance -= amount

        else:
            print("Enter Valid Number")

        return f"total balance : {self.balance}"
            
        
    def withdraw(self, amount):
        if amount <= 0:
            print("withdrawal must be positive")
        elif amount <= self.balance:
            self.balance-=amount
        else:
            print("Insufficient Balance")

        return f"Total Balance : {self.balance}"

    
acc = BankAccount(1000)
print(acc.deposit(500))
print(acc.withdraw(2000))
# Out:
# total balance : 1500
# Insufficient Balance
# Total Balance : 1500

# %% [markdown]
# ## 2. Instance vs Class Attributes

# %%
class Employee:
    company = "Sunflower"
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

e1 = Employee("Priya", 100000)
e2 = Employee("Manas", 100000)
print(e1.company, e2.company)

Employee.company = "NewSunflower"
print(e1.company, e2.company)

e1.salary = 2000000
print(e1.salary, e2.salary)
# Out:
# Sunflower Sunflower
# NewSunflower NewSunflower
# 2000000 100000

# %% [markdown]
# ## Practice:
#
# Create a Car class with a class attribute wheels = 4 and instance attributes make/model. Prove that changing wheels on the class affects all instances, but changing it on one instance does not.

# %%
class Car:
    wheels = 4

    def __init__(self, make, model):
        self.make = make
        self.model = model

cars = Car("Mahindra", "Thar")
print(cars.make, cars.model)
print(Car.wheels)
cars2 = Car("Mahindra", "Thar")
print(cars2.make, cars2.model)
cars.wheels=10
print(cars2.wheels)

Car.wheels = 8
print(Car.wheels)
# Out:
# Mahindra Thar
# 4
# Mahindra Thar
# 4
# 8

# %% [markdown]
# ## 3. Encapsulation
#
# Controlling access to internal data.

# %%
class Account:
    def __init__(self, balance):
        self._balance = balance
        self.__pin = "4567"

    def get_balance(self):
        return self._balance

    def deposit(self, amount):
        if amount > 0:
            self._balance += amount
        else:
            raise ValueError("Amount must be positive")

acc = Account(1000)
print(acc.get_balance())
# acc.__pin        -> AttributeError
print(acc._Account__pin)
# Out:
# 1000
# 4567

# %% [markdown]
# ## Practice:
#
# Build a Password class that stores a password as a private attribute and exposes only a check(guess) method returning True/False. Never let the password be printed directly.

# %%
class Password:
    def __init__(self):
        self.__password = "Priya369"

    def check(self, password):
        if self.__password == password:
            return True
        else:
            return False

p = Password()
print(p.check("priya369"))
print(p.check("Priya369"))
#print(p.__password)
# Out:
# False
# True

# %% [markdown]
# ## 4. Properties (Getters/Setters, Pythonic Style)

# %% [markdown]
# You need @property when you want to add logic behind the scenes (like validation, logging, or computation) but keep the same clean syntax (obj.x instead of obj.get_x()).
#
# Without @property, you're forced to choose between:
#
# Public attributes: Fast and simple, but you can't add validation or logic later without breaking code.
# Methods: Safe and flexible, but code becomes cluttered with .get_x() and .set_x().
#
# With @property, you get the best of both:
#
# Clean syntax: obj.balance = 100
# Hidden logic: Validation runs automatically behind the scenes.
# Real-world scenario: Imagine you have a User class with a username attribute.

# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius

    @property
    def radius(self):
        return self._radius

    @radius.setter
    def radius(self, value):
        if value <= 0:
            raise ValueError("Radius must be positive")
        self._radius = value

    @property
    def area(self):
        return 3.14159*self._radius**2

c = Circle(5)
print(c.area)
c.radius = 10
# c.area = 5
# Out:
# 78.53975

# %% [markdown]
# ## Practice:
# Add a @property for diameter to Circle that's computed from radius, and a setter for diameter that updates radius accordingly.

# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius

    @property
    def radius(self):
        return self._radius

    @radius.setter
    def radius(self, value):
        if value <= 0:
            raise ValueError("Radius must be positive")
        self._radius = value

    @property
    def diameter(self):
        return self._radius * 2

    @diameter.setter
    def diameter(self, value):
        if value <= 0:
            raise ValueError("Diameter must be positive")
        self._radius = value / 2   # updates radius under the hood

    @property
    def area(self):
        return 3.14159 * self._radius ** 2

c = Circle(5)
print(c.diameter)   # 10
c.diameter = 20
print(c.radius)     # 10.0
# Out:
# 10
# 10.0

# %% [markdown]
# ## 5. Inheritance

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return "..."

class Cat(Animal):
    def speak(self):
        return f"{self.name} says Meow" 

class Dog(Animal):
    def speak(self):
        return f"{self.name} says Woof"

for a in [Cat("Whiskers"), Dog("Rex")]:
    print(a.speak())
# Out:
# Whiskers says Meow
# Rex says Woof

# %% [markdown]
# ## super()

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand =  brand

class Car(Vehicle):
    def __init__(self, brand, model):
        super().__init__(brand)
        self.model = model

c = Car("Toyota", "Corolla")
print(c.brand, c.model)
# Out:
# Toyota Corolla

# %% [markdown]
# ## Practice:
# Create a base class Shape with a method area() that raises NotImplementedError. Create Rectangle and Triangle subclasses that override area() properly.

# %%
class Shape:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        raise NotImplementedError

class Rectangle(Shape):
    def area(self):
        return self.length * self.width

class Triangle(Shape):
    def area(self):
        return (self.length * self.width) / 2

a = Rectangle(5, 5)
print(a.area())   # 25

try:
    b = Shape(3, 2)
    b.area()
except NotImplementedError:
    print("Shape.area() must be overridden by a subclass")         # raises NotImplementedError
# Out:
# 25
# Shape.area() must be overridden by a subclass

# %% [markdown]
# ## 6. Polymorphism
#
# Same interface, different behavior depending on the object.

# %%
class Shape:
    def area(self):
        raise NotImplementedError

class Square(Shape):
    def __init__(self, side):
        self.side = side
    def area(self):
        return self.side**2

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return 3.14159 * self.radius **2

shapes = [Square(4), Circle(3)]
for s in shapes:
    print(type(s).__name__, "->", s.area())
# Out:
# Square -> 16
# Circle -> 28.27431

# %% [markdown]
# ## Practice:
#  Write a function total_area(shapes) that sums .area() across any list of shape-like objects, without knowing their exact classes.

# %%
class Shape:
    def area(self):
        raise NotImplementedError

class Square(Shape):
    def __init__(self, side):
        self.side = side
    def area(self):
        return self.side**2

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return 3.14159 * self.radius **2



shapes = [Square(4), Circle(3)]


for s in shapes:
    print(type(s).__name__, "->", s.area())

def total_area(shapes):
    return sum(s.area() for s in shapes)
print(total_area(shapes))
# Out:
# Square -> 16
# Circle -> 28.27431
# 44.27431

# %% [markdown]
# ## 7. Abstraction (Abstract Base Classes)

# %%
from abc import ABC, abstractmethod

class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, amount):
        pass

class CreditCard(PaymentMethod):
    def pay(self, amount):
        return f"Paid {amount} via Credit Card"

class UPI(PaymentMethod):
    def pay(self, amount):
        return f"Paid {amount} via UPI"

pm = CreditCard()
print(pm.pay(1000))
# Out:
# Paid 1000 via Credit Card

# %% [markdown]
# ## Practice:
# Define an abstract Notifier class with an abstract method send(message). Implement EmailNotifier and SMSNotifier.

# %%
from abc import ABC, abstractmethod

class Notifier(ABC):
    @abstractmethod
    def send(self, message):
        pass
class EmailNotifier(Notifier):
    def send(self, message):
        return f"You got an Email"

class SMSNotifier(Notifier):
    def send(self, message):
        return f"You got an SMS"

msge = SMSNotifier()
print(msge.send("----"))
# Out:
# You got an SMS

# %% [markdown]
# ## 8. Dunder (Magic) Methods
#
# These let your objects work naturally with Python's built-in syntax.
#
# Common dunders: __init__, __repr__, __str__, __eq__, __lt__, __add__, __len__, __getitem__, __iter__, __call__, __enter__/__exit__ (context managers).

# %%
class Vector:
    def __init__(self, x, y):
        self.x, self.y = x, y

    def __repr__(self):                 # developer-facing representation
        return f"Vector({self.x}, {self.y})"

    def __str__(self):                  # user-facing string
        return f"({self.x}, {self.y})"

    def __add__(self, other):           # enables v1 + v2
        return Vector(self.x + other.x, self.y + other.y)

    def __eq__(self, other):            # enables v1 == v2
        return self.x == other.x and self.y == other.y

    def __len__(self):                  # enables len(v)
        return int((self.x**2 + self.y**2) ** 0.5)

v1 = Vector(1, 2)
v2 = Vector(3, 4)
print(v1 + v2)     # (4, 6)
print(v1 == Vector(1, 2))  # True
print(len(v2))     # 5
# Out:
# (4, 6)
# True
# 5

# %% [markdown]
# ## Practice:
# Give Vector __sub__, __mul__ (scalar multiplication), and __lt__ (compare by magnitude).

# %%
import math
class Vector:
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def __sub__(self, other):
        return Vector(self.x - other.x, self.y - other.y)

    def __mul__(self, scalar):
        return Vector(self.x * scalar, self.y * scalar)

    def __repr__(self):
        return f"Vector({self.x}, {self.y})"

    def __lt__(self, other):
        return math.sqrt(self.x**2 + self.y**2) < math.sqrt(other.x**2 + other.y**2)

v3 = Vector(1,7)
v4 = Vector(2,4)
print(v3-v4)
print(v3*3)
print(v4<v3)
# Out:
# Vector(-1, 3)
# Vector(3, 21)
# True

# %% [markdown]
# ## 9. Class Methods vs Static Methods vs Instance Methods

# %%
class Pizza:
    def __init__(self, toppings):
        self.toppings = toppings
    
    def describe(self):
        return f"Pizza with {', '.join(self.toppings)}"

    @classmethod
    def margherita(cls):
        return cls(["tomato","mozzarella"])

    @staticmethod
    def is_valid_topping(topping):
        return topping in {"cheese","tomato","mozzarella","olive","basil"}

p = Pizza.margherita()
print(p.describe())
print(Pizza.is_valid_topping("olive"))
# Out:
# Pizza with tomato, mozzarella
# True
